# %%
from ollama import chat
from ollama import ChatResponse

response: ChatResponse = chat(model='gemma3', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)

# %%
from ollama import Client

client = Client(host="http://157.26.83.15/ollama/")
response = client.chat(
    model="qwen3:4b",
    messages=[{
        "role": "user", 
        "content": "Hello"}]
)

print(response["message"]["content"])
# Out:
# Hello! 😊 How can I assist you today?

# %%
from langchain_ollama import ChatOllama

# Connect to a specific host (e.g., another machine on the network)
llm = ChatOllama(
    model="deepseek-r1:70b", #"qwen3.5:122b-131k",
    base_url="http://157.26.83.15/ollama/" # Change to your Ollama host IP
)

# Test the connection
response = llm.invoke("Hello")
print(response)

# %%
from langchain_ollama import ChatOllama

# Connect to a specific host (e.g., another machine on the network)
llm = ChatOllama(
    model="gemma4:26b",
    base_url="http://157.26.83.15/ollama/" # Change to your Ollama host IP
)

# Test the connection
response = llm.invoke("Hello")
print(response)
# Out:
# content='Hello! How can I help you today?' additional_kwargs={} response_metadata={'model': 'gemma4:26b', 'created_at': '2026-04-15T19:14:05.232137785Z', 'done': True, 'done_reason': 'stop', 'total_duration': 36366425063, 'load_duration': 35293428008, 'prompt_eval_count': 16, 'prompt_eval_duration': 48957749, 'eval_count': 80, 'eval_duration': 618019633, 'logprobs': None, 'model_name': 'gemma4:26b', 'model_provider': 'ollama'} id='lc_run--019d9290-131a-7db1-af4c-ce390ede2cfd-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 80, 'total_tokens': 96}
